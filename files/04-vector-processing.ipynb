# %%
import geopandas as gpd

# %%
wells = gpd.read_file("data/brogmwvolledigeset.zip")

# %%
fields = gpd.read_file("fields_cropped.shp")

# %%
wells.plot(markersize=0.1)
# Out:
# <Axes: >

# %%
fields.plot()
# Out:
# <Axes: >

# %%
fields.crs
# Out:
# <Projected CRS: EPSG:28992>
# Name: Amersfoort / RD New
# Axis Info [cartesian]:
# - X[east]: Easting (metre)
# - Y[north]: Northing (metre)
# Area of Use:
# - name: Netherlands - onshore, including Waddenzee, Dutch Wadden Islands and 12-mile offshore coastal zone.
# - bounds: (3.2, 50.75, 7.22, 53.7)
# Coordinate Operation:
# - name: RD New
# - method: Oblique Stereographic
# Datum: Amersfoort
# - Ellipsoid: Bessel 1841
# - Prime Meridian: Greenwich

# %%
wells = wells.to_crs(epsg=28992)

# %%
wells.crs
# Out:
# <Projected CRS: EPSG:28992>
# Name: Amersfoort / RD New
# Axis Info [cartesian]:
# - X[east]: Easting (metre)
# - Y[north]: Northing (metre)
# Area of Use:
# - name: Netherlands - onshore, including Waddenzee, Dutch Wadden Islands and 12-mile offshore coastal zone.
# - bounds: (3.2, 50.75, 7.22, 53.7)
# Coordinate Operation:
# - name: RD New
# - method: Oblique Stereographic
# Datum: Amersfoort
# - Ellipsoid: Bessel 1841
# - Prime Meridian: Greenwich

# %%
wells_clip = wells.clip(fields)

# %%
wells_clip
# Out:
#                 bro_id delivery_accountable_party quality_regime  \
# 37326  GMW000000046390                   27364178        IMBRO/A
# 40703  GMW000000043444                   27364178        IMBRO/A
# 39471  GMW000000045048                   27364178        IMBRO/A
# 19445  GMW000000024992                   50200097        IMBRO/A
# 40174  GMW000000043963                   27364178        IMBRO/A
# ...                ...                        ...            ...
# 38624  GMW000000045994                   27364178        IMBRO/A
# 39248  GMW000000044430                   27364178        IMBRO/A
# 40422  GMW000000044026                   27364178        IMBRO/A
# 38779  GMW000000045404                   27364178        IMBRO/A
# 16926  GMW000000025310                   50200097        IMBRO/A
#
#       with_prehistory   delivery_context construction_standard  \
# 37326              ja  archiefoverdracht              onbekend
# 40703              ja  archiefoverdracht              onbekend
# 39471              ja  archiefoverdracht              onbekend
# 19445              ja  archiefoverdracht              onbekend
# 40174              ja  archiefoverdracht              onbekend
# ...               ...                ...                   ...
# 38624              ja  archiefoverdracht              onbekend
# 39248              ja  archiefoverdracht              onbekend
# 40422              ja  archiefoverdracht              onbekend
# 38779              ja  archiefoverdracht              onbekend
# 16926              ja  archiefoverdracht              onbekend
#
#       initial_function removed  number_of_monitoring_tubes groundlevel_stable  \
# 37326            stand     nee                         2.0                 ja
# 40703            stand      ja                         1.0                nee
# 39471            stand     nee                         1.0                nee
# 19445            stand     nee                         1.0                 ja
# 40174            stand     nee                         1.0                nee
# ...                ...     ...                         ...                ...
# 38624            stand      ja                         1.0                nee
# 39248            stand      ja                         1.0                nee
# 40422            stand      ja                         1.0                 ja
# 38779            stand     nee                         1.0                 ja
# 16926            stand     nee                         1.0                 ja
#
#        ... corrected latest_correction_time under_review under_review_time  \
# 37326  ...       nee                    NaN          nee               NaN
# 40703  ...       nee                    NaN          nee               NaN
# 39471  ...       nee                    NaN          nee               NaN
# 19445  ...       nee                    NaN          nee               NaN
# 40174  ...       nee                    NaN          nee               NaN
# ...    ...       ...                    ...          ...               ...
# 38624  ...       nee                    NaN          nee               NaN
# 39248  ...       nee                    NaN          nee               NaN
# 40422  ...       nee                    NaN          nee               NaN
# 38779  ...       nee                    NaN          nee               NaN
# 16926  ...       nee                    NaN          nee               NaN
#
#       deregistered deregistration_time reregistered reregistration_time  \
# 37326          nee                 NaN          nee                 NaN
# 40703          nee                 NaN          nee                 NaN
# 39471          nee                 NaN          nee                 NaN
# 19445          nee                 NaN          nee                 NaN
# 40174          nee                 NaN          nee                 NaN
# ...            ...                 ...          ...                 ...
# 38624          nee                 NaN          nee                 NaN
# 39248          nee                 NaN          nee                 NaN
# 40422          nee                 NaN          nee                 NaN
# 38779          nee                 NaN          nee                 NaN
# 16926          nee                 NaN          nee                 NaN
#
#       coordinate_transformation                       geometry
# 37326            RDNAPTRANS2008  POINT (125500.001 494650.001)
# 40703            RDNAPTRANS2008  POINT (127050.001 496040.001)
# 39471         RDNAPTRANS2008MV0  POINT (127050.001 496040.001)
# 19445            RDNAPTRANS2008  POINT (121980.001 500180.001)
# 40174            RDNAPTRANS2008  POINT (130840.000 491095.001)
# ...                         ...                            ...
# 38624         RDNAPTRANS2008MV0  POINT (133160.001 497960.000)
# 39248            RDNAPTRANS2008  POINT (133160.001 497960.000)
# 40422            RDNAPTRANS2008  POINT (133220.001 497974.999)
# 38779         RDNAPTRANS2008MV0  POINT (133220.001 497974.999)
# 16926            RDNAPTRANS2008  POINT (132780.002 498710.000)
#
# [79 rows x 40 columns]

# %%
wells_clip.plot()
# Out:
# <Axes: >

# %%
fields.crs
# Out:
# <Projected CRS: EPSG:28992>
# Name: Amersfoort / RD New
# Axis Info [cartesian]:
# - X[east]: Easting (metre)
# - Y[north]: Northing (metre)
# Area of Use:
# - name: Netherlands - onshore, including Waddenzee, Dutch Wadden Islands and 12-mile offshore coastal zone.
# - bounds: (3.2, 50.75, 7.22, 53.7)
# Coordinate Operation:
# - name: RD New
# - method: Oblique Stereographic
# Datum: Amersfoort
# - Ellipsoid: Bessel 1841
# - Prime Meridian: Greenwich

# %%
buffer = fields.buffer(50)

# %%
buffer
# Out:
# 0       POLYGON ((120034.247 496377.370, 120032.906 49...
# 1       POLYGON ((120104.003 496668.702, 120104.096 49...
# 2       POLYGON ((119841.664 496010.205, 119841.301 49...
# 3       POLYGON ((120215.138 496633.530, 120213.141 49...
# 4       POLYGON ((119925.887 495988.419, 119921.425 49...
#                               ...
# 4867    POLYGON ((133375.343 492581.329, 133371.801 49...
# 4868    POLYGON ((133366.099 492940.838, 133365.991 49...
# 4869    POLYGON ((133392.579 492772.924, 133393.816 49...
# 4870    POLYGON ((133449.777 492701.029, 133444.983 49...
# 4871    POLYGON ((133280.554 492677.360, 133281.927 49...
# Length: 4872, dtype: geometry

# %%
fields_buffer = fields.copy()

# %%
fields_buffer["geometry"] = buffer

# %%
fields_buffer
# Out:
#       category                                         gewas  gewascode  jaar  \
# 0     Grasland                            Grasland, blijvend        265  2020
# 1     Grasland                            Grasland, blijvend        265  2020
# 2     Grasland                            Grasland, blijvend        265  2020
# 3     Grasland                            Grasland, blijvend        265  2020
# 4     Grasland  Grasland, natuurlijk. Hoofdfunctie landbouw.        331  2020
# ...        ...                                           ...        ...   ...
# 4867  Grasland  Grasland, natuurlijk. Hoofdfunctie landbouw.        331  2020
# 4868  Grasland  Grasland, natuurlijk. Hoofdfunctie landbouw.        331  2020
# 4869  Grasland                            Grasland, blijvend        265  2020
# 4870  Grasland  Grasland, natuurlijk. Hoofdfunctie landbouw.        331  2020
# 4871  Grasland  Grasland, natuurlijk. Hoofdfunctie landbouw.        331  2020
#
#           status                                           geometry
# 0     Definitief  POLYGON ((120034.247 496377.370, 120032.906 49...
# 1     Definitief  POLYGON ((120104.003 496668.702, 120104.096 49...
# 2     Definitief  POLYGON ((119841.664 496010.205, 119841.301 49...
# 3     Definitief  POLYGON ((120215.138 496633.530, 120213.141 49...
# 4     Definitief  POLYGON ((119925.887 495988.419, 119921.425 49...
# ...          ...                                                ...
# 4867  Definitief  POLYGON ((133375.343 492581.329, 133371.801 49...
# 4868  Definitief  POLYGON ((133366.099 492940.838, 133365.991 49...
# 4869  Definitief  POLYGON ((133392.579 492772.924, 133393.816 49...
# 4870  Definitief  POLYGON ((133449.777 492701.029, 133444.983 49...
# 4871  Definitief  POLYGON ((133280.554 492677.360, 133281.927 49...
#
# [4872 rows x 6 columns]

# %%
fields_buffer.plot()
# Out:
# <Axes: >

# %%
fields_buffer_dissolve = fields_buffer.dissolve()

# %%
fields_buffer_dissolve.plot()
# Out:
# <Axes: >

# %%
fields_buffer_dissolve
# Out:
#                                             geometry  category  \
# 0  MULTIPOLYGON (((120135.730 492480.424, 120133....  Grasland
#
#                 gewas  gewascode  jaar      status
# 0  Grasland, blijvend        265  2020  Definitief

# %%
wells_buffer = wells.clip(fields_buffer_dissolve)

# %%
wells_buffer.plot()
# Out:
# <Axes: >

# %%
wells_buffer
# Out:
#                 bro_id delivery_accountable_party quality_regime  \
# 25305  GMW000000032114                   34366966        IMBRO/A
# 51902  GMW000000054133                   50200097        IMBRO/A
# 28141  GMW000000033322                   34366966          IMBRO
# 27007  GMW000000033522                   34366966        IMBRO/A
# 28068  GMW000000034289                   34362354        IMBRO/A
# ...                ...                        ...            ...
# 38624  GMW000000045994                   27364178        IMBRO/A
# 39248  GMW000000044430                   27364178        IMBRO/A
# 40422  GMW000000044026                   27364178        IMBRO/A
# 38779  GMW000000045404                   27364178        IMBRO/A
# 16926  GMW000000025310                   50200097        IMBRO/A
#
#       with_prehistory   delivery_context construction_standard  \
# 25305              ja       publiekeTaak              onbekend
# 51902              ja  archiefoverdracht              onbekend
# 28141             nee       publiekeTaak               NEN5766
# 27007              ja       publiekeTaak              onbekend
# 28068              ja  archiefoverdracht              onbekend
# ...               ...                ...                   ...
# 38624              ja  archiefoverdracht              onbekend
# 39248              ja  archiefoverdracht              onbekend
# 40422              ja  archiefoverdracht              onbekend
# 38779              ja  archiefoverdracht              onbekend
# 16926              ja  archiefoverdracht              onbekend
#
#       initial_function removed  number_of_monitoring_tubes groundlevel_stable  \
# 25305            stand     nee                         3.0                nee
# 51902            stand     nee                         2.0                nee
# 28141            stand     nee                         1.0                nee
# 27007            stand     nee                         1.0                nee
# 28068            stand     nee                         6.0                nee
# ...                ...     ...                         ...                ...
# 38624            stand      ja                         1.0                nee
# 39248            stand      ja                         1.0                nee
# 40422            stand      ja                         1.0                 ja
# 38779            stand     nee                         1.0                 ja
# 16926            stand     nee                         1.0                 ja
#
#        ... corrected latest_correction_time under_review under_review_time  \
# 25305  ...       nee                    NaN          nee               NaN
# 51902  ...       nee                    NaN          nee               NaN
# 28141  ...       nee                    NaN          nee               NaN
# 27007  ...       nee                    NaN          nee               NaN
# 28068  ...       nee                    NaN          nee               NaN
# ...    ...       ...                    ...          ...               ...
# 38624  ...       nee                    NaN          nee               NaN
# 39248  ...       nee                    NaN          nee               NaN
# 40422  ...       nee                    NaN          nee               NaN
# 38779  ...       nee                    NaN          nee               NaN
# 16926  ...       nee                    NaN          nee               NaN
#
#       deregistered deregistration_time reregistered reregistration_time  \
# 25305          nee                 NaN          nee                 NaN
# 51902          nee                 NaN          nee                 NaN
# 28141          nee                 NaN          nee                 NaN
# 27007          nee                 NaN          nee                 NaN
# 28068          nee                 NaN          nee                 NaN
# ...            ...                 ...          ...                 ...
# 38624          nee                 NaN          nee                 NaN
# 39248          nee                 NaN          nee                 NaN
# 40422          nee                 NaN          nee                 NaN
# 38779          nee                 NaN          nee                 NaN
# 16926          nee                 NaN          nee                 NaN
#
#       coordinate_transformation                       geometry
# 25305            RDNAPTRANS2008  POINT (121039.001 493192.002)
# 51902            RDNAPTRANS2008  POINT (121100.002 497640.002)
# 28141            RDNAPTRANS2008  POINT (122381.301 491718.001)
# 27007            RDNAPTRANS2008  POINT (121989.001 492262.002)
# 28068            RDNAPTRANS2008  POINT (126455.000 491091.001)
# ...                         ...                            ...
# 38624         RDNAPTRANS2008MV0  POINT (133160.001 497960.000)
# 39248            RDNAPTRANS2008  POINT (133160.001 497960.000)
# 40422            RDNAPTRANS2008  POINT (133220.001 497974.999)
# 38779         RDNAPTRANS2008MV0  POINT (133220.001 497974.999)
# 16926            RDNAPTRANS2008  POINT (132780.002 498710.000)
#
# [187 rows x 40 columns]

# %%
from matplotlib import pyplot as plt

fig, ax = plt.subplots(1,1)
wells_buffer.plot(ax=ax, color='r')
fields.plot(ax=ax)
# Out:
# <Axes: >

# %%
xmin, ymin, xmax, ymax = fields.total_bounds

# %%
xmin
# Out:
# 119594.38399999963

# %%
wells = gpd.read_file("data/brogmwvolledigeset.zip")

# %%
wells = wells.to_crs(28992)

# %%
wells.plot(markersize=0.1)
# Out:
# <Axes: >

# %%
wells_cx = wells.cx[xmin-500:xmax+500, ymin-500:ymax+500]

# %%
wells_cx.plot()
# Out:
# <Axes: >

# %%
# wells_cx_buffer = wells_cx.buffer(500)
wells_cx_buffer = wells_cx.copy()
wells_cx_buffer["geometry"] = wells_cx.buffer(500)

# %%
wells_cx_buffer
# Out:
#                 bro_id delivery_accountable_party quality_regime  \
# 1136   GMW000000005275                   27364178        IMBRO/A
# 1220   GMW000000005361                   27364178        IMBRO/A
# 1256   GMW000000005369                   27364178        IMBRO/A
# 1280   GMW000000005343                   27364178        IMBRO/A
# 1375   GMW000000005460                   27364178        IMBRO/A
# ...                ...                        ...            ...
# 53325  GMW000000061826                   34366966          IMBRO
# 53443  GMW000000060709                   34366966          IMBRO
# 53444  GMW000000060710                   34366966          IMBRO
# 53449  GMW000000060467                   34366966          IMBRO
# 53450  GMW000000060468                   34366966          IMBRO
#
#       with_prehistory delivery_context construction_standard initial_function  \
# 1136               ja     publiekeTaak              onbekend            stand
# 1220               ja     publiekeTaak              onbekend            stand
# 1256               ja     publiekeTaak              onbekend            stand
# 1280               ja     publiekeTaak              onbekend            stand
# 1375               ja     publiekeTaak              onbekend            stand
# ...               ...              ...                   ...              ...
# 53325             nee     publiekeTaak               NEN5104            stand
# 53443             nee     publiekeTaak               NEN5766            stand
# 53444             nee     publiekeTaak               NEN5766            stand
# 53449             nee     publiekeTaak                  geen            stand
# 53450             nee     publiekeTaak                  geen            stand
#
#       removed  number_of_monitoring_tubes groundlevel_stable  ... corrected  \
# 1136      nee                         1.0                 ja  ...       nee
# 1220      nee                         1.0                 ja  ...       nee
# 1256      nee                         1.0                 ja  ...       nee
# 1280      nee                         1.0                 ja  ...       nee
# 1375      nee                         1.0                 ja  ...       nee
# ...       ...                         ...                ...  ...       ...
# 53325     nee                         1.0                nee  ...       nee
# 53443     nee                         1.0                nee  ...       nee
# 53444     nee                         1.0                nee  ...       nee
# 53449     nee                         1.0                 ja  ...       nee
# 53450     nee                         2.0                 ja  ...       nee
#
#       latest_correction_time under_review under_review_time deregistered  \
# 1136                     NaN          nee               NaN          nee
# 1220                     NaN          nee               NaN          nee
# 1256                     NaN          nee               NaN          nee
# 1280                     NaN          nee               NaN          nee
# 1375                     NaN          nee               NaN          nee
# ...                      ...          ...               ...          ...
# 53325                    NaN          nee               NaN          nee
# 53443                    NaN          nee               NaN          nee
# 53444                    NaN          nee               NaN          nee
# 53449                    NaN          nee               NaN          nee
# 53450                    NaN          nee               NaN          nee
#
#       deregistration_time reregistered reregistration_time  \
# 1136                  NaN          nee                 NaN
# 1220                  NaN          nee                 NaN
# 1256                  NaN          nee                 NaN
# 1280                  NaN          nee                 NaN
# 1375                  NaN          nee                 NaN
# ...                   ...          ...                 ...
# 53325                 NaN          nee                 NaN
# 53443                 NaN          nee                 NaN
# 53444                 NaN          nee                 NaN
# 53449                 NaN          nee                 NaN
# 53450                 NaN          nee                 NaN
#
#       coordinate_transformation  \
# 1136             RDNAPTRANS2008
# 1220             RDNAPTRANS2008
# 1256             RDNAPTRANS2008
# 1280             RDNAPTRANS2008
# 1375             RDNAPTRANS2008
# ...                         ...
# 53325            RDNAPTRANS2018
# 53443            RDNAPTRANS2018
# 53444            RDNAPTRANS2018
# 53449            RDNAPTRANS2018
# 53450            RDNAPTRANS2018
#
#                                                 geometry
# 1136   POLYGON ((123227.188 492431.740, 123224.780 49...
# 1220   POLYGON ((123132.429 492566.311, 123130.021 49...
# 1256   POLYGON ((123098.108 492366.141, 123095.701 49...
# 1280   POLYGON ((123050.418 492400.260, 123048.011 49...
# 1375   POLYGON ((123070.758 492333.910, 123068.350 49...
# ...                                                  ...
# 53325  POLYGON ((124034.941 490080.013, 124032.533 49...
# 53443  POLYGON ((121503.951 487189.012, 121501.543 48...
# 53444  POLYGON ((122888.850 485440.209, 122886.442 48...
# 53449  POLYGON ((130247.526 485211.114, 130245.118 48...
# 53450  POLYGON ((130077.026 485243.714, 130074.618 48...
#
# [2264 rows x 40 columns]

# %%
fields_wells_buffer_clip = fields.clip(wells_cx_buffer, keep_geom_type=True)

# %%
fields_wells_buffer.plot()
# Out:
# <Axes: >

# %%
# Out:
# <Axes: >
