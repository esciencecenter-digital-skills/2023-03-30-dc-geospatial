# %%
import geopandas as gpd

# %%
wells = gpd.read_file("data/brogmwvolledigeset.zip")

# %%
fields = gpd.read_file("fields_cropped.shp")

# %%
wells_10rows = gpd.read_file("data/brogmwvolledigeset.zip", rows=10)

# %%
wells_10rows
# Out:
#             bro_id delivery_accountable_party quality_regime with_prehistory  \
# 0  GMW000000003627                   01182779        IMBRO/A              ja
# 1  GMW000000003637                   01182779        IMBRO/A              ja
# 2  GMW000000003647                   01182779        IMBRO/A              ja
# 3  GMW000000003657                   01182779        IMBRO/A              ja
# 4  GMW000000003667                   01182779        IMBRO/A              ja
# 5  GMW000000003677                   01182779        IMBRO/A              ja
# 6  GMW000000003687                   01182779        IMBRO/A              ja
# 7  GMW000000003697                   01182779        IMBRO/A              ja
# 8  GMW000000003781                   27370927          IMBRO             nee
# 9  GMW000000003821                        NaN            NaN             NaN
#
#     delivery_context construction_standard initial_function removed  \
# 0  archiefoverdracht              onbekend            stand     nee
# 1  archiefoverdracht              onbekend            stand     nee
# 2  archiefoverdracht              onbekend            stand     nee
# 3  archiefoverdracht              onbekend            stand     nee
# 4  archiefoverdracht              onbekend            stand     nee
# 5  archiefoverdracht              onbekend            stand     nee
# 6  archiefoverdracht              onbekend            stand     nee
# 7  archiefoverdracht              onbekend            stand     nee
# 8       publiekeTaak                  geen            stand     nee
# 9                NaN                   NaN              NaN     NaN
#
#    number_of_monitoring_tubes groundlevel_stable  ... corrected  \
# 0                         1.0           onbekend  ...       nee
# 1                         1.0           onbekend  ...       nee
# 2                         1.0           onbekend  ...       nee
# 3                         2.0           onbekend  ...       nee
# 4                         1.0           onbekend  ...       nee
# 5                         1.0           onbekend  ...       nee
# 6                         1.0           onbekend  ...       nee
# 7                         1.0           onbekend  ...       nee
# 8                         1.0                nee  ...       nee
# 9                         NaN                NaN  ...       NaN
#
#   latest_correction_time under_review under_review_time deregistered  \
# 0                    NaN          nee               NaN          nee
# 1                    NaN          nee               NaN          nee
# 2                    NaN          nee               NaN          nee
# 3                    NaN          nee               NaN          nee
# 4                    NaN          nee               NaN          nee
# 5                    NaN          nee               NaN          nee
# 6                    NaN          nee               NaN          nee
# 7                    NaN          nee               NaN          nee
# 8                    NaN          nee               NaN          nee
# 9                    NaN          NaN               NaN           ja
#
#          deregistration_time  reregistered reregistration_time  \
# 0                        NaN           nee                 NaN
# 1                        NaN           nee                 NaN
# 2                        NaN           nee                 NaN
# 3                        NaN           nee                 NaN
# 4                        NaN           nee                 NaN
# 5                        NaN           nee                 NaN
# 6                        NaN           nee                 NaN
# 7                        NaN           nee                 NaN
# 8                        NaN           nee                 NaN
# 9  2019-03-27T10:59:11+01:00           NaN                 NaN
#
#   coordinate_transformation                  geometry
# 0            RDNAPTRANS2008  POINT (6.39896 53.25112)
# 1            RDNAPTRANS2008  POINT (6.43067 53.27177)
# 2            RDNAPTRANS2008  POINT (6.39401 53.30246)
# 3            RDNAPTRANS2008  POINT (6.32138 53.28649)
# 4            RDNAPTRANS2008  POINT (6.30042 53.26036)
# 5            RDNAPTRANS2008  POINT (6.24741 53.26420)
# 6            RDNAPTRANS2008  POINT (6.39731 53.26382)
# 7            RDNAPTRANS2008  POINT (6.40563 53.24110)
# 8            RDNAPTRANS2008  POINT (4.31424 52.07304)
# 9                       NaN                      None
#
# [10 rows x 40 columns]

# %%
wells_10rows.crs
# Out:
# <Geographic 2D CRS: EPSG:4258>
# Name: ETRS89
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: Europe - onshore and offshore: Albania; Andorra; Austria; Belgium; Bosnia and Herzegovina; Bulgaria; Croatia; Cyprus; Czechia; Denmark; Estonia; Faroe Islands; Finland; France; Germany; Gibraltar; Greece; Hungary; Ireland; Italy; Kosovo; Latvia; Liechtenstein; Lithuania; Luxembourg; Malta; Moldova; Monaco; Montenegro; Netherlands; North Macedonia; Norway including Svalbard and Jan Mayen; Poland; Portugal; Romania; San Marino; Serbia; Slovakia; Slovenia; Spain; Sweden; Switzerland; United Kingdom (UK) including Channel Islands and Isle of Man; Vatican City State.
# - bounds: (-16.1, 32.88, 40.18, 84.73)
# Datum: European Terrestrial Reference System 1989 ensemble
# - Ellipsoid: GRS 1980
# - Prime Meridian: Greenwich

# %%
wells.crs
# Out:
# <Geographic 2D CRS: EPSG:4258>
# Name: ETRS89
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: Europe - onshore and offshore: Albania; Andorra; Austria; Belgium; Bosnia and Herzegovina; Bulgaria; Croatia; Cyprus; Czechia; Denmark; Estonia; Faroe Islands; Finland; France; Germany; Gibraltar; Greece; Hungary; Ireland; Italy; Kosovo; Latvia; Liechtenstein; Lithuania; Luxembourg; Malta; Moldova; Monaco; Montenegro; Netherlands; North Macedonia; Norway including Svalbard and Jan Mayen; Poland; Portugal; Romania; San Marino; Serbia; Slovakia; Slovenia; Spain; Sweden; Switzerland; United Kingdom (UK) including Channel Islands and Isle of Man; Vatican City State.
# - bounds: (-16.1, 32.88, 40.18, 84.73)
# Datum: European Terrestrial Reference System 1989 ensemble
# - Ellipsoid: GRS 1980
# - Prime Meridian: Greenwich

# %%
fields.crs
# Out:
# <Projected CRS: EPSG:28992>
# Name: Amersfoort / RD New
# Axis Info [cartesian]:
# - X[east]: Easting (metre)
# - Y[north]: Northing (metre)
# Area of Use:
# - name: Netherlands - onshore, including Waddenzee, Dutch Wadden Islands and 12-mile offshore coastal zone.
# - bounds: (3.2, 50.75, 7.22, 53.7)
# Coordinate Operation:
# - name: RD New
# - method: Oblique Stereographic
# Datum: Amersfoort
# - Ellipsoid: Bessel 1841
# - Prime Meridian: Greenwich

# %%
wells = wells.to_crs(fields.crs)

# %%
wells.crs
# Out:
# <Projected CRS: EPSG:28992>
# Name: Amersfoort / RD New
# Axis Info [cartesian]:
# - X[east]: Easting (metre)
# - Y[north]: Northing (metre)
# Area of Use:
# - name: Netherlands - onshore, including Waddenzee, Dutch Wadden Islands and 12-mile offshore coastal zone.
# - bounds: (3.2, 50.75, 7.22, 53.7)
# Coordinate Operation:
# - name: RD New
# - method: Oblique Stereographic
# Datum: Amersfoort
# - Ellipsoid: Bessel 1841
# - Prime Meridian: Greenwich

# %%
xmin, ymin, xmax, ymax = fields.total_bounds

# %%
wells_cx = wells.cx[xmin-500:xmax+500, ymin-500:ymax+500]

# %%
wells_cx.plot()
# Out:
# <Axes: >

# %%
buffer = wells_cx.buffer(500)

# %%
wells_cx
# Out:
#                 bro_id delivery_accountable_party quality_regime  \
# 1136   GMW000000005275                   27364178        IMBRO/A
# 1220   GMW000000005361                   27364178        IMBRO/A
# 1256   GMW000000005369                   27364178        IMBRO/A
# 1280   GMW000000005343                   27364178        IMBRO/A
# 1375   GMW000000005460                   27364178        IMBRO/A
# ...                ...                        ...            ...
# 53325  GMW000000061826                   34366966          IMBRO
# 53443  GMW000000060709                   34366966          IMBRO
# 53444  GMW000000060710                   34366966          IMBRO
# 53449  GMW000000060467                   34366966          IMBRO
# 53450  GMW000000060468                   34366966          IMBRO
#
#       with_prehistory delivery_context construction_standard initial_function  \
# 1136               ja     publiekeTaak              onbekend            stand
# 1220               ja     publiekeTaak              onbekend            stand
# 1256               ja     publiekeTaak              onbekend            stand
# 1280               ja     publiekeTaak              onbekend            stand
# 1375               ja     publiekeTaak              onbekend            stand
# ...               ...              ...                   ...              ...
# 53325             nee     publiekeTaak               NEN5104            stand
# 53443             nee     publiekeTaak               NEN5766            stand
# 53444             nee     publiekeTaak               NEN5766            stand
# 53449             nee     publiekeTaak                  geen            stand
# 53450             nee     publiekeTaak                  geen            stand
#
#       removed  number_of_monitoring_tubes groundlevel_stable  ... corrected  \
# 1136      nee                         1.0                 ja  ...       nee
# 1220      nee                         1.0                 ja  ...       nee
# 1256      nee                         1.0                 ja  ...       nee
# 1280      nee                         1.0                 ja  ...       nee
# 1375      nee                         1.0                 ja  ...       nee
# ...       ...                         ...                ...  ...       ...
# 53325     nee                         1.0                nee  ...       nee
# 53443     nee                         1.0                nee  ...       nee
# 53444     nee                         1.0                nee  ...       nee
# 53449     nee                         1.0                 ja  ...       nee
# 53450     nee                         2.0                 ja  ...       nee
#
#       latest_correction_time under_review under_review_time deregistered  \
# 1136                     NaN          nee               NaN          nee
# 1220                     NaN          nee               NaN          nee
# 1256                     NaN          nee               NaN          nee
# 1280                     NaN          nee               NaN          nee
# 1375                     NaN          nee               NaN          nee
# ...                      ...          ...               ...          ...
# 53325                    NaN          nee               NaN          nee
# 53443                    NaN          nee               NaN          nee
# 53444                    NaN          nee               NaN          nee
# 53449                    NaN          nee               NaN          nee
# 53450                    NaN          nee               NaN          nee
#
#       deregistration_time reregistered reregistration_time  \
# 1136                  NaN          nee                 NaN
# 1220                  NaN          nee                 NaN
# 1256                  NaN          nee                 NaN
# 1280                  NaN          nee                 NaN
# 1375                  NaN          nee                 NaN
# ...                   ...          ...                 ...
# 53325                 NaN          nee                 NaN
# 53443                 NaN          nee                 NaN
# 53444                 NaN          nee                 NaN
# 53449                 NaN          nee                 NaN
# 53450                 NaN          nee                 NaN
#
#       coordinate_transformation                       geometry
# 1136             RDNAPTRANS2008  POINT (122727.241 492431.721)
# 1220             RDNAPTRANS2008  POINT (122632.482 492566.291)
# 1256             RDNAPTRANS2008  POINT (122598.161 492366.122)
# 1280             RDNAPTRANS2008  POINT (122550.471 492400.241)
# 1375             RDNAPTRANS2008  POINT (122570.811 492333.891)
# ...                         ...                            ...
# 53325            RDNAPTRANS2018  POINT (123535.000 490080.000)
# 53443            RDNAPTRANS2018  POINT (121004.000 487189.000)
# 53444            RDNAPTRANS2018  POINT (122388.900 485440.200)
# 53449            RDNAPTRANS2018  POINT (129747.600 485211.100)
# 53450            RDNAPTRANS2018  POINT (129577.100 485243.700)
#
# [2264 rows x 40 columns]

# %%
buffer
# Out:
# 1136     POLYGON ((123227.241 492431.721, 123224.833 49...
# 1220     POLYGON ((123132.482 492566.291, 123130.074 49...
# 1256     POLYGON ((123098.161 492366.122, 123095.754 49...
# 1280     POLYGON ((123050.471 492400.241, 123048.063 49...
# 1375     POLYGON ((123070.811 492333.891, 123068.403 49...
#                                ...
# 53325    POLYGON ((124035.000 490080.000, 124032.592 49...
# 53443    POLYGON ((121504.000 487189.000, 121501.592 48...
# 53444    POLYGON ((122888.900 485440.200, 122886.492 48...
# 53449    POLYGON ((130247.600 485211.100, 130245.192 48...
# 53450    POLYGON ((130077.100 485243.700, 130074.692 48...
# Length: 2264, dtype: geometry

# %%
wells_cx_buffer = wells_cx.copy()

# %%
wells_cx_buffer
# Out:
#                 bro_id delivery_accountable_party quality_regime  \
# 1136   GMW000000005275                   27364178        IMBRO/A
# 1220   GMW000000005361                   27364178        IMBRO/A
# 1256   GMW000000005369                   27364178        IMBRO/A
# 1280   GMW000000005343                   27364178        IMBRO/A
# 1375   GMW000000005460                   27364178        IMBRO/A
# ...                ...                        ...            ...
# 53325  GMW000000061826                   34366966          IMBRO
# 53443  GMW000000060709                   34366966          IMBRO
# 53444  GMW000000060710                   34366966          IMBRO
# 53449  GMW000000060467                   34366966          IMBRO
# 53450  GMW000000060468                   34366966          IMBRO
#
#       with_prehistory delivery_context construction_standard initial_function  \
# 1136               ja     publiekeTaak              onbekend            stand
# 1220               ja     publiekeTaak              onbekend            stand
# 1256               ja     publiekeTaak              onbekend            stand
# 1280               ja     publiekeTaak              onbekend            stand
# 1375               ja     publiekeTaak              onbekend            stand
# ...               ...              ...                   ...              ...
# 53325             nee     publiekeTaak               NEN5104            stand
# 53443             nee     publiekeTaak               NEN5766            stand
# 53444             nee     publiekeTaak               NEN5766            stand
# 53449             nee     publiekeTaak                  geen            stand
# 53450             nee     publiekeTaak                  geen            stand
#
#       removed  number_of_monitoring_tubes groundlevel_stable  ... corrected  \
# 1136      nee                         1.0                 ja  ...       nee
# 1220      nee                         1.0                 ja  ...       nee
# 1256      nee                         1.0                 ja  ...       nee
# 1280      nee                         1.0                 ja  ...       nee
# 1375      nee                         1.0                 ja  ...       nee
# ...       ...                         ...                ...  ...       ...
# 53325     nee                         1.0                nee  ...       nee
# 53443     nee                         1.0                nee  ...       nee
# 53444     nee                         1.0                nee  ...       nee
# 53449     nee                         1.0                 ja  ...       nee
# 53450     nee                         2.0                 ja  ...       nee
#
#       latest_correction_time under_review under_review_time deregistered  \
# 1136                     NaN          nee               NaN          nee
# 1220                     NaN          nee               NaN          nee
# 1256                     NaN          nee               NaN          nee
# 1280                     NaN          nee               NaN          nee
# 1375                     NaN          nee               NaN          nee
# ...                      ...          ...               ...          ...
# 53325                    NaN          nee               NaN          nee
# 53443                    NaN          nee               NaN          nee
# 53444                    NaN          nee               NaN          nee
# 53449                    NaN          nee               NaN          nee
# 53450                    NaN          nee               NaN          nee
#
#       deregistration_time reregistered reregistration_time  \
# 1136                  NaN          nee                 NaN
# 1220                  NaN          nee                 NaN
# 1256                  NaN          nee                 NaN
# 1280                  NaN          nee                 NaN
# 1375                  NaN          nee                 NaN
# ...                   ...          ...                 ...
# 53325                 NaN          nee                 NaN
# 53443                 NaN          nee                 NaN
# 53444                 NaN          nee                 NaN
# 53449                 NaN          nee                 NaN
# 53450                 NaN          nee                 NaN
#
#       coordinate_transformation  \
# 1136             RDNAPTRANS2008
# 1220             RDNAPTRANS2008
# 1256             RDNAPTRANS2008
# 1280             RDNAPTRANS2008
# 1375             RDNAPTRANS2008
# ...                         ...
# 53325            RDNAPTRANS2018
# 53443            RDNAPTRANS2018
# 53444            RDNAPTRANS2018
# 53449            RDNAPTRANS2018
# 53450            RDNAPTRANS2018
#
#                                                 geometry
# 1136   POLYGON ((123227.241 492431.721, 123224.833 49...
# 1220   POLYGON ((123132.482 492566.291, 123130.074 49...
# 1256   POLYGON ((123098.161 492366.122, 123095.754 49...
# 1280   POLYGON ((123050.471 492400.241, 123048.063 49...
# 1375   POLYGON ((123070.811 492333.891, 123068.403 49...
# ...                                                  ...
# 53325  POLYGON ((124035.000 490080.000, 124032.592 49...
# 53443  POLYGON ((121504.000 487189.000, 121501.592 48...
# 53444  POLYGON ((122888.900 485440.200, 122886.492 48...
# 53449  POLYGON ((130247.600 485211.100, 130245.192 48...
# 53450  POLYGON ((130077.100 485243.700, 130074.692 48...
#
# [2264 rows x 40 columns]

# %%
wells_cx_buffer["geometry"] = buffer

# %%
wells_cx_buffer.plot()
# Out:
# <Axes: >

# %%
fields_wells_cx_buffer = fields.sjoin(wells_cx_buffer)

# %%
fields_wells_cx_buffer.plot()
# Out:
# <Axes: >

# %%
fields_wells_cx_buffer.shape
# Out:
# (11420, 46)

# %%
fields.shape
# Out:
# (4872, 6)

# %%
fields_wells_cx_buffer.index
# Out:
# Int64Index([   0,    2,    4,    5,   14,   16,   17,   18,   41,    0,
#             ...
#             4789, 4790, 4791, 4797, 4799, 4801, 4802, 4777, 4798, 4803],
#            dtype='int64', length=11420)

# %%
index = fields_wells_cx_buffer.index.unique()

# %%
fields_selected = fields.iloc[index]

# %%
fields_selected.plot()
# Out:
# <Axes: >

# %%
fields_selected.to_file("fields_selected.gpkg")
